# %% [markdown]
# # Chapter 5: Eager and Lazy APIs

# %%
import polars as pl
pl.__version__  # The book is built with Polars version 1.20.0
# Out:
# '1.37.1'

# %% [markdown]
# ## Eager API: DataFrame

# %%
# %%time
trips = pl.read_parquet("data/taxi/yellow_tripdata_2022-01.parquet")  
sum_per_vendor = trips.group_by("VendorID").sum()  

income_per_distance_per_vendor = sum_per_vendor.select(
    "VendorID",
    income_per_distance=pl.col("total_amount") / pl.col("trip_distance"),
)

top_three = income_per_distance_per_vendor.sort(  
    by="income_per_distance", descending=True
).head(3)

top_three
# Out:
# CPU times: user 299 ms, sys: 93.5 ms, total: 392 ms
# Wall time: 472 ms
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'trips = pl.read_parquet("data/taxi/yellow_tripdata_2022-01.parquet")  \nsum_per_vendor = trips.group_by("VendorID").sum()  \n\nincome_per_distance_per_vendor = sum_per_vendor.select(\n    "VendorID",\n    income_per_distance=pl.col("total_amount") / pl.col("trip_distance"),\n)\n\ntop_three = income_per_distance_per_vendor.sort(  \n    by="income_per_distance", descending=True\n).head(3)\n\ntop_three\n')
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/magics/execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/magics/execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/polars/dataframe/group_by.py:855, in GroupBy.sum(self)
#     829 def sum(self) -> DataFrame:
#     830     """
#     831     Reduce the groups to the sum.
#     832
#    (...)    853     └────────┴─────┴──────┴─────┘
#     854     """
# --> 855     return self.agg(F.all().sum())
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/polars/dataframe/group_by.py:298, in GroupBy.agg(self, *aggs, **named_aggs)
#     195 """
#     196 Compute aggregations for each group of a group by operation.
#     197
#    (...)    291 └─────┴───────┴────────────────┘
#     292 """
#     293 from polars.lazyframe.opt_flags import QueryOptFlags
#     295 return (
#     296     self._lgb()
#     297     .agg(*aggs, **named_aggs)
# --> 298     .collect(optimizations=QueryOptFlags.none())
#     299 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/polars/lazyframe/opt_flags.py:324, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     321         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     323 kwargs["optimizations"] = optflags
# --> 324 return function(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/polars/lazyframe/frame.py:2429, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2427 # Only for testing purposes
#    2428 callback = _kwargs.get("post_opt_callback", callback)
# -> 2429 return wrap_df(ldf.collect(engine, callback))
#
# InvalidOperationError: `sum` operation not supported for dtype `str`
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
# DF ["VendorID", "tpep_pickup_datetime", "tpep_dropoff_datetime", "passenger_count", ...]; PROJECT */19 COLUMNS

# %% [markdown]
# ## Lazy API: LazyFrame

# %%
# This raises a SchemaError:
# names_lf = pl.LazyFrame({"name": ["Alice", "Bob", "Charlie"], "age": [25, 30, 35]})

# erroneous_query = names_lf.with_columns(
#     sliced_age=pl.col("age").str.slice(1, 3)
# )

# result_df = erroneous_query.collect()

# %% [markdown]
# ## Performance Differences

# %%
# %%time
trips = pl.scan_parquet("data/taxi/yellow_tripdata_*.parquet")
sum_per_vendor = trips.group_by("VendorID").sum()

income_per_distance_per_vendor = sum_per_vendor.select(
    "VendorID",
    income_per_distance=pl.col("total_amount") / pl.col("trip_distance"),
)

top_three = income_per_distance_per_vendor.sort(
    by="income_per_distance", descending=True
).head(3)

top_three.collect()

# %%
lf = pl.LazyFrame({"col1": [1, 2, 3], "col2": [4, 5, 6]})

# ... Some heavy computation ...

print(lf.collect())

print(lf.with_columns(pl.col("col1") + 1).collect())

# %% [markdown]
# ## Functionality Differences

# %% [markdown]
# ### Attributes

# %% [markdown]
# ### Aggregation Methods

# %% [markdown]
# ### Computation Methods

# %% [markdown]
# ### Descriptive Methods

# %% [markdown]
# ### GroupBy Methods

# %% [markdown]
# ### Exporting Methods

# %% [markdown]
# ### Manipulation and Selection Methods

# %% [markdown]
# ### Miscellaneous Methods

# %% [markdown]
# ## Tips and Tricks

# %% [markdown]
# ### Going from LazyFrame to DataFrame and Vice Versa

# %% [markdown]
# ### Joining a DataFrame with a LazyFrame

# %%
# This raises a TypeError:
# big_sales_data = pl.LazyFrame(
#     {"sale_id": [101, 102, 103], "amount": [250, 150, 300]}
# )
#
# sales_metadata = pl.DataFrame(
#     {"sale_id": [101, 102, 103], "category": ["A", "B", "A"]}
# )
#
# big_sales_data.join(sales_metadata, on="sale_id").collect()

# %%
big_sales_data = pl.LazyFrame(
    {"sale_id": [101, 102, 103], "amount": [250, 150, 300]}
)

sales_metadata = pl.DataFrame(
    {"sale_id": [101, 102, 103], "category": ["A", "B", "A"]}
)

big_sales_data.join(sales_metadata.lazy(), on="sale_id").collect()

# %% [markdown]
# ### Caching Intermittent Results

# %%
lf = pl.LazyFrame({"col1": [1, 2, 3], "col2": [4, 5, 6]})

# ... Some heavy computation ...

lf = lf.collect().lazy()  
print(lf.collect())

print(lf.with_columns(pl.col("col1") + 1).collect())

# %% [markdown]
# ## Takeaways
